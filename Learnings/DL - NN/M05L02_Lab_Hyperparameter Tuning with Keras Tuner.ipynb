# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Hyperparameter Tuning with Keras Tuner**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will learn how to set up Keras Tuner and prepare the environment for hyperparameter tuning.
#
# ## Learning objectives:
# By the end of this lab, you will:
# - Install Keras Tuner and import the necessary libraries
# - Load and preprocess the MNIST data set
# - Define a model-building function that uses hyperparameters to configure the model architecture
# - Set up Keras Tuner to search for the best hyperparameter configuration
# - Retrieve the best hyperparameters from the search and build a model with these optimized values
#
# ## Prerequisites:
# - Basic understanding of Python programming
# - Keras and TensorFlow installed

# %% [markdown]
# ### Exercise 1: Install the Keras Tuner
#
# This exercise guides you through the initial setup for using Keras Tuner. You install the library, import necessary modules, and load and preprocess the MNIST data set, which will be used for hyperparameter tuning.
# 1. **Install Keras Tuner:**
#     - Use pip to install Keras Tuner
# 2. **Import necessary libraries:**
#     - Import Keras Tuner, TensorFlow, and Keras modules
# 3. **Load and preprocess the MNIST data set:**
#     - Load the MNIST data set.
#     - Normalize the data set by dividing by 255.0.

# %%
# !pip install tensorflow
# !pip install keras-tuner
# !pip install numpy
# Out:
# Requirement already satisfied: tensorflow in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (2.17.1)
# Requirement already satisfied: tensorflow-intel==2.17.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\parid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.1->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\parid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.1->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (3.11.3)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.1->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\parid\appdata\roaming\python\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow) (0.1.2)
# Requirement already satisfied: keras-tuner in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras-tuner) (3.11.3)
# Requirement already satisfied: packaging in c:\users\parid\appdata\roaming\python\python312\site-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras-tuner) (2.32.4)
# Requirement already satisfied: kt-legacy in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (2.3.1)
# Requirement already satisfied: numpy in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (14.2.0)
# Requirement already satisfied: namex in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (3.15.1)
# Requirement already satisfied: optree in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (0.17.0)
# Requirement already satisfied: ml-dtypes in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests->keras-tuner) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests->keras-tuner) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from rich->keras->keras-tuner) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\parid\appdata\roaming\python\python312\site-packages (from rich->keras->keras-tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Requirement already satisfied: numpy in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (1.26.4)

# %% [markdown]
# #### Explanation:
# This code installs the necessary libraries using pip
#
# - **TensorFlow**: Ensures compatibility with the Keras Tuner.
# - **Keras Tuner**: The version used in this lab.
# - **Numpy**: Ensures compatibility with the other installed packages.

# %%
import sys

# Increase recursion limit to prevent potential issues
sys.setrecursionlimit(100000)

# %% [markdown]
# #### Explanation:
# The sys.setrecursionlimit function is used to increase the recursion limit, which helps prevent potential recursion errors when running complex models with deep nested functions or when using certain libraries like TensorFlow.

# %%
# Step 2: Import necessary libraries
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam
import os
import warnings

# Suppress all Python warnings
warnings.filterwarnings('ignore')

# Set TensorFlow log level to suppress warnings and info messages
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 0 = all logs, 1 = filter out INFO, 2 = filter out INFO and WARNING, 3 = ERROR only

# %%
# !pip install scikit-learn
from tensorflow import keras
from sklearn.model_selection import train_test_split

# Load the MNIST dataset
(x_all, y_all), _ = keras.datasets.mnist.load_data()

# Flatten and normalize the images
x_all = x_all.reshape((x_all.shape[0], -1)).astype("float32") / 255.0

# Split into train+val and test (80/20)
x_temp, x_test, y_temp, y_test = train_test_split(x_all, y_all, test_size=0.2, random_state=42)

# Split train+val into train and validation (75/25 of 80% = 60/20 overall)
x_train, x_val, y_train, y_val = train_test_split(x_temp, y_temp, test_size=0.25, random_state=42)
# Out:
# Requirement already satisfied: scikit-learn in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from scikit-learn) (3.6.0)

# %% [markdown]
# #### Explanation
#
# This code imports the necessary libraries:
#
# - **`keras_tuner`**: Used for hyperparameter tuning.
# - **`Sequential`**: A linear stack of layers in Keras.
# - **`Dense`**, **`Flatten`**: Common Keras layers.
# - **`mnist`**: The MNIST dataset, a standard dataset for image classification.
# - **`Adam`**: An optimizer in Keras.

# %%
# Step 3: Load and preprocess the MNIST dataset
(x_train, y_train), (x_val, y_val) = mnist.load_data()
x_train, x_val = x_train / 255.0, x_val / 255.0

print(f'Training data shape: {x_train.shape}')
print(f'Validation data shape: {x_val.shape}')
# Out:
# Training data shape: (60000, 28, 28)
# Validation data shape: (10000, 28, 28)

# %% [markdown]
# #### Explanation
#
# This code loads the MNIST dataset and preprocesses it:
#
# - **`mnist.load_data()`**: Loads the dataset, returning training and validation splits.
# - **`x_train / 255.0`**: Normalizes the pixel values to be between 0 and 1.
# - **`print(f'...')`**: Displays the shapes of the training and validation datasets.

# %% [markdown]
# ### Exercise 2: Defining the model with hyperparameters
#
# In this exercise, you define a model-building function that uses the `HyperParameters` object to specify the number of units in a dense layer and the learning rate. This function returns a compiled Keras model that is ready for hyperparameter tuning.
#
# **Define a model-building function:**
# - Create a function `build_model` that takes a `HyperParameters` object as input.
# - Use the `HyperParameters` object to define the number of units in a dense layer and the learning rate for the optimizer.
# - Compile the model with sparse categorical cross-entropy loss and Adam optimizer.

# %%
# Define a model-building function 

def build_model(hp):
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'),
        Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# #### Explanation
#
# This function builds and compiles a Keras model with hyperparameters:
#
# - **`hp.Int('units', ...)`**: Defines the number of units in the Dense layer as a hyperparameter.
# - **`hp.Float('learning_rate', ...)`**: Defines the learning rate as a hyperparameter.
# - **`model.compile()`**: Compiles the model with the Adam optimizer and sparse categorical cross-entropy loss.

# %% [markdown]
# ### Exercise 3: Configuring the hyperparameter search
#
# This exercise guides you through configuring Keras Tuner. You create a `RandomSearch` tuner, specifying the model-building function, the optimization objective, the number of trials, and the directory for storing results. The search space summary provides an overview of the hyperparameters being tuned.
#
# **Create a RandomSearch Tuner:**
# - Use the `RandomSearch` class from Keras Tuner.
# - Specify the model-building function, optimization objective (validation accuracy), number of trials, and directory for storing results.

# %%
# Create a RandomSearch Tuner 

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='intro_to_kt'
)

# Display a summary of the search space 
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %% [markdown]
# #### Explanation
#
# This code sets up a Keras Tuner `RandomSearch`:
#
# - **`build_model`**: The model-building function.
# - **`objective='val_accuracy'`**: The metric to optimize (validation accuracy).
# - **`max_trials=10`**: The maximum number of different hyperparameter configurations to try.
# - **`executions_per_trial=2`**: The number of times to run each configuration.
# - **`directory='my_dir'`**: Directory to save the results.
# - **`project_name='intro_to_kt'`**: Name of the project for organizing results.
#
# Displays a summary of the hyperparameter search space, providing an overview of the hyperparameters being tuned.

# %% [markdown]
# ### Exercise 4: Running the hyperparameter search
#
# In this exercise, you run the hyperparameter search using the `search` method of the tuner. You provide the training and validation data along with the number of epochs. After the search is complete, the results summary displays the best hyperparameter configurations found.
#
# **Run the search:**
# - Use the `search` method of the tuner.
# - Pass in the training data, validation data, and the number of epochs

# %%
# Run the hyperparameter search 
tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val)) 

# Display a summary of the results 
tuner.results_summary()
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Run the hyperparameter search
# ----> 2 tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val))
#       4 # Display a summary of the results
#       5 tuner.results_summary()
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:225, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     223 while True:
#     224     self.pre_create_trial()
# --> 225     trial = self.oracle.create_trial(self.tuner_id)
#     226     if trial.status == trial_module.TrialStatus.STOPPED:
#     227         # Oracle triggered exit.
#     228         break
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\oracle.py:108, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     106     LOCKS[oracle].acquire()
#     107     THREADS[oracle] = thread_name
# --> 108 ret_val = func(*args, **kwargs)
#     109 if need_acquire:
#     110     THREADS[oracle] = None
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\oracle.py:497, in Oracle.create_trial(self, tuner_id)
#     495 self.trials[trial_id] = trial
#     496 self.start_order.append(trial_id)
# --> 497 self._save_trial(trial)
#     498 self.save()
#     499 self._display.on_trial_begin(trial)
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\oracle.py:805, in Oracle._save_trial(self, trial)
#     802 def _save_trial(self, trial):
#     803     # Write trial status to trial directory
#     804     trial_id = trial.trial_id
# --> 805     trial.save(os.path.join(self._get_trial_dir(trial_id), "trial.json"))
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\oracle.py:799, in Oracle._get_trial_dir(self, trial_id)
#     797 def _get_trial_dir(self, trial_id):
#     798     dirname = os.path.join(self._project_dir, f"trial_{str(trial_id)}")
# --> 799     utils.create_directory(dirname)
#     800     return dirname
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\utils.py:44, in create_directory(path, remove_existing)
#      41 def create_directory(path, remove_existing=False):
#      42     # Create the directory if it doesn't exist.
#      43     if not backend.io.exists(path):
# ---> 44         backend.io.makedirs(path)
#      46     # If it does exist, and remove_existing is specified,
#      47     # the directory will be removed and recreated.
#      48     elif remove_existing:
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\backend\io.py:58, in makedirs(path)
#      56 if tf is None:
#      57     return os.makedirs(path, exist_ok=True)
# ---> 58 return tf.io.gfile.makedirs(path)
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\tensorflow\python\lib\io\file_io.py:513, in recursive_create_dir_v2(path)
#     501 @tf_export("io.gfile.makedirs")
#     502 def recursive_create_dir_v2(path):
#     503   """Creates a directory and all parent/intermediate directories.
#     504
#     505   It succeeds if path already exists and is writable.
#    (...)
#     511     errors.OpError: If the operation fails.
#     512   """
# --> 513   _pywrap_file_io.RecursivelyCreateDir(compat.path_to_bytes(path))
#
# FailedPreconditionError: my_dir\intro_to_kt is not a directory

# %% [markdown]
# #### Explanation
#
# This command runs the hyperparameter search:
#
# - **`epochs=5`**: Each trial is trained for 5 epochs.
# - **`validation_data=(x_val, y_val)`**: The validation data to evaluate the model's performance during the search.
#
# After the search is complete, this command displays a summary of the best hyperparameter configurations found during the search.

# %% [markdown]
# ## Exercise 5: Analyzing and using the best hyperparameters
#
# In this exercise, you retrieve the best hyperparameters found during the search and print their values. You then build a model with these optimized hyperparameters and train it on the full training data set. Finally, you evaluate the model’s performance on the test set to ensure that it performs well with the selected hyperparameters.
#
# **Retrieve the best hyperparameters:**
# - Use the `get_best_hyperparameters` method to get the best hyperparameters.
# - Print the optimal values for the hyperparameters.
#
# **Build and train the model:**
# - Build a model using the best hyperparameters.
# - Train the model on the full training data set and evaluate its performance on the test set.

# %%
# Step 1: Retrieve the best hyperparameters 

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0] 
print(f""" 

The optimal number of units in the first dense layer is {best_hps.get('units')}. 

The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}. 

""") 

# Step 2: Build and Train the Model with Best Hyperparameters 
model = tuner.hypermodel.build(best_hps) 
model.fit(x_train, y_train, epochs=10, validation_split=0.2) 

# Evaluate the model on the test set 
test_loss, test_acc = model.evaluate(x_val, y_val) 
print(f'Test accuracy: {test_acc}')
# Out:
#
#
# The optimal number of units in the first dense layer is 32.
#
# The optimal learning rate for the optimizer is 0.008212458838617381.
#
#
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9156 - loss: 0.2820 - val_accuracy: 0.9467 - val_loss: 0.1775
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9471 - loss: 0.1778 - val_accuracy: 0.9481 - val_loss: 0.1828
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9535 - loss: 0.1567 - val_accuracy: 0.9426 - val_loss: 0.2183
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9582 - loss: 0.1420 - val_accuracy: 0.9550 - val_loss: 0.1768
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9610 - loss: 0.1338 - val_accuracy: 0.9492 - val_loss: 0.2058
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9630 - loss: 0.1279 - val_accuracy: 0.9391 - val_loss: 0.2406
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9643 - loss: 0.1205 - val_accuracy: 0.9548 - val_loss: 0.1917
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9663 - loss: 0.1141 - val_accuracy: 0.9559 - val_loss: 0.1995
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9686 - loss: 0.1056 - val_accuracy: 0.9538 - val_loss: 0.1914
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9693 - loss: 0.1032 - val_accuracy: 0.9560 - val_loss: 0.2148
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9523 - loss: 0.2109
# Test accuracy: 0.9523000121116638

# %% [markdown]
# #### Explanation
#
# This code retrieves the best hyperparameters found during the search:
#
# - **`get_best_hyperparameters(num_trials=1)`**: Gets the best hyperparameter configuration.
# - **`print(f"...")`**: Prints the best hyperparameters.
# - **`model.fit(...)`**: Trains the model on the full training data with a validation split of 20%.
# - **`model.evaluate(...)`**: Evaluates the model on the test (validation) dataset and prints the accuracy, which gives an indication of how well the model generalizes.

# %% [markdown]
# ## Practice exercises
#
# ### Exercise 1: Setting Up Keras Tuner
#
# #### Objective:
# Learn how to set up Keras Tuner and prepare the environment for hyperparameter tuning.
#
# #### Instructions:
# 1. Install Keras Tuner.
# 2. Import necessary libraries.
# 3. Load and preprocess the MNIST data set.

# %%
# Write your code here
# !pip install keras-tuner 

# Step 2: Import necessary libraries 
import keras_tuner as kt 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Flatten 
from tensorflow.keras.datasets import mnist 
from tensorflow.keras.optimizers import Adam 

# Step 3: Load and preprocess the MNIST data set 
(x_train, y_train), (x_val, y_val) = mnist.load_data() 
x_train, x_val = x_train / 255.0, x_val / 255.0 

# Print the shapes of the training and validation datasets
print(f'Training data shape: {x_train.shape}') 
print(f'Validation data shape: {x_val.shape}')
# Out:
# Requirement already satisfied: keras-tuner in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras-tuner) (3.11.3)
# Requirement already satisfied: packaging in c:\users\parid\appdata\roaming\python\python312\site-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras-tuner) (2.32.4)
# Requirement already satisfied: kt-legacy in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (2.3.1)
# Requirement already satisfied: numpy in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (14.2.0)
# Requirement already satisfied: namex in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (3.15.1)
# Requirement already satisfied: optree in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (0.17.0)
# Requirement already satisfied: ml-dtypes in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests->keras-tuner) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from requests->keras-tuner) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from rich->keras->keras-tuner) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\parid\appdata\roaming\python\python312\site-packages (from rich->keras->keras-tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\parid\anaconda3\envs\rohit\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Training data shape: (60000, 28, 28)
# Validation data shape: (10000, 28, 28)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# !pip install keras-tuner
#
# # Step 2: Import necessary libraries
# import keras_tuner as kt
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Flatten
# from tensorflow.keras.datasets import mnist
# from tensorflow.keras.optimizers import Adam
#
# # Step 3: Load and preprocess the MNIST data set
# (x_train, y_train), (x_val, y_val) = mnist.load_data()
# x_train, x_val = x_train / 255.0, x_val / 255.0
#
# # Print the shapes of the training and validation datasets
# print(f'Training data shape: {x_train.shape}')
# print(f'Validation data shape: {x_val.shape}')
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2: Defining the model with hyperparameters
#
# #### Objective:
# Define a model-building function that uses hyperparameters to configure the model architecture.
#
# #### Instructions:
# 1. Define a model-building function that uses the `HyperParameters` object to specify the number of units in a dense layer and the learning rate.
# 2. Compile the model with sparse categorical cross-entropy loss and Adam optimizer.

# %%
# Write your code here
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import keras_tuner as kt

# Step 1: Define a model-building function
def build_model(hp):
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'),
        Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Flatten
# from tensorflow.keras.optimizers import Adam
# import keras_tuner as kt
#
# # Step 1: Define a model-building function
# def build_model(hp):
#     model = Sequential([
#         Flatten(input_shape=(28, 28)),
#         Dense(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'),
#         Dense(10, activation='softmax')
#     ])
#
#     model.compile(
#         optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
#         loss='sparse_categorical_crossentropy',
#         metrics=['accuracy']
#     )
#
#     return model
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3: Configuring the hyperparameter search
#
# #### Objective:
# Set up Keras Tuner to search for the best hyperparameter configuration.
#
# #### Instructions:
# 1. Create a `RandomSearch` tuner using the model-building function.
# 2. Specify the optimization objective, number of trials, and directory for storing results.

# %%
# Write your code here
import keras_tuner as kt

# Step 1: Create a RandomSearch Tuner
tuner = kt.RandomSearch(
    build_model,  # Ensure 'build_model' function is defined from previous code
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='intro_to_kt'
)

# Display a summary of the search space
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# import keras_tuner as kt
#
# # Step 1: Create a RandomSearch Tuner
# tuner = kt.RandomSearch(
#     build_model,  # Ensure 'build_model' function is defined from previous code
#     objective='val_accuracy',
#     max_trials=10,
#     executions_per_trial=2,
#     directory='my_dir',
#     project_name='intro_to_kt'
# )
#
# # Display a summary of the search space
# tuner.search_space_summary()
# ```
#
# </details>

# %% [markdown]
# ### Exercise 4: Running the hyperparameter search
#
# #### Objective:
# Run the hyperparameter search and dispaly the summary of the results.
#
# #### Instructions:
# 1. Run the hyperparameter search using the `search` method of the tuner.
# 2. Pass in the training data, validation data, and the number of epochs.
# 3. Display a summary of the results.

# %%
# Write your code here
# Step 1: Run the hyperparameter search 

tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val)) 

 # Display a summary of the results 

tuner.results_summary()
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# Cell In[27], line 4
#       1 # Write your code here
#       2 # Step 1: Run the hyperparameter search
# ----> 4 tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val))
#       6  # Display a summary of the results
#       8 tuner.results_summary()
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:225, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     223 while True:
#     224     self.pre_create_trial()
# --> 225     trial = self.oracle.create_trial(self.tuner_id)
#     226     if trial.status == trial_module.TrialStatus.STOPPED:
#     227         # Oracle triggered exit.
#     228         break
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\oracle.py:108, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     106     LOCKS[oracle].acquire()
#     107     THREADS[oracle] = thread_name
# --> 108 ret_val = func(*args, **kwargs)
#     109 if need_acquire:
#     110     THREADS[oracle] = None
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\oracle.py:497, in Oracle.create_trial(self, tuner_id)
#     495 self.trials[trial_id] = trial
#     496 self.start_order.append(trial_id)
# --> 497 self._save_trial(trial)
#     498 self.save()
#     499 self._display.on_trial_begin(trial)
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\oracle.py:805, in Oracle._save_trial(self, trial)
#     802 def _save_trial(self, trial):
#     803     # Write trial status to trial directory
#     804     trial_id = trial.trial_id
# --> 805     trial.save(os.path.join(self._get_trial_dir(trial_id), "trial.json"))
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\engine\oracle.py:799, in Oracle._get_trial_dir(self, trial_id)
#     797 def _get_trial_dir(self, trial_id):
#     798     dirname = os.path.join(self._project_dir, f"trial_{str(trial_id)}")
# --> 799     utils.create_directory(dirname)
#     800     return dirname
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\utils.py:44, in create_directory(path, remove_existing)
#      41 def create_directory(path, remove_existing=False):
#      42     # Create the directory if it doesn't exist.
#      43     if not backend.io.exists(path):
# ---> 44         backend.io.makedirs(path)
#      46     # If it does exist, and remove_existing is specified,
#      47     # the directory will be removed and recreated.
#      48     elif remove_existing:
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\keras_tuner\src\backend\io.py:58, in makedirs(path)
#      56 if tf is None:
#      57     return os.makedirs(path, exist_ok=True)
# ---> 58 return tf.io.gfile.makedirs(path)
#
# File c:\Users\parid\anaconda3\envs\Rohit\Lib\site-packages\tensorflow\python\lib\io\file_io.py:513, in recursive_create_dir_v2(path)
#     501 @tf_export("io.gfile.makedirs")
#     502 def recursive_create_dir_v2(path):
#     503   """Creates a directory and all parent/intermediate directories.
#     504
#     505   It succeeds if path already exists and is writable.
#    (...)
#     511     errors.OpError: If the operation fails.
#     512   """
# --> 513   _pywrap_file_io.RecursivelyCreateDir(compat.path_to_bytes(path))
#
# FailedPreconditionError: my_dir\intro_to_kt is not a directory

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# # Step 1: Run the hyperparameter search
#
# tuner.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val))
#
#  # Display a summary of the results
#
# tuner.results_summary()
# ```
#
# </details>

# %% [markdown]
# ### Exercise 5: Analyzing and using the best hyperparameters
#
# #### Objective:
# Retrieve the best hyperparameters from the search and build a model with these optimized values.
#
# #### Instructions:
# 1. Retrieve the best hyperparameters using the `get_best_hyperparameters` method.
# 2. Build a model using the best hyperparameters.
# 3. Train the model on the full training data set and evaluate its performance on the validation set.

# %%
# Write your code here
# Step 1: Retrieve the best hyperparameters 

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0] 

print(f""" 

The optimal number of units in the first dense layer is {best_hps.get('units')}. 

The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}. 

""") 

 # Step 2: Build and train the model with best hyperparameters 

model = tuner.hypermodel.build(best_hps) 

model.fit(x_train, y_train, epochs=10, validation_split=0.2) 

 # Evaluate the model on the validation set 

val_loss, val_acc = model.evaluate(x_val, y_val) 

print(f'Validation accuracy: {val_acc}')

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# # Step 1: Retrieve the best hyperparameters
#
# best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# print(f"""
#
# The optimal number of units in the first dense layer is {best_hps.get('units')}.
#
# The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.
#
# """)
#
#  # Step 2: Build and train the model with best hyperparameters
#
# model = tuner.hypermodel.build(best_hps)
#
# model.fit(x_train, y_train, epochs=10, validation_split=0.2)
#
#  # Evaluate the model on the validation set
#
# val_loss, val_acc = model.evaluate(x_val, y_val)
#
# print(f'Validation accuracy: {val_acc}')
# ```
#
# </details>

# %% [markdown]
# ### Conclusion
#
# Congratulations on completing this lab! You have learned to set up Keras Tuner and prepare the environment for hyperparameter tuning. In addition, you defined a model-building function that uses hyperparameters to configure the model architecture. You configured Keras Tuner to search for the best hyperparameter configuration and learned to run the hyperparameter search and analyze the results. Finally, you retrieved the best hyperparameters and built a model with these optimized values.

# %% [markdown]
# ## Authors

# %% [markdown]
# Skillup

# %% [markdown]
# Copyright ©IBM Corporation. All rights reserved.
