# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer


class SelfAttention(Layer):
    def __init__(self, d_model):
        super(SelfAttention, self).__init__()
        self.d_model = d_model
        self.query_dense = tf.keras.layers.Dense(d_model)
        self.key_dense = tf.keras.layers.Dense(d_model)
        self.value_dense = tf.keras.layers.Dense(d_model)
    
    def call(self, inputs):
        q = self.query_dense(inputs)
        k = self.key_dense(inputs)
        v = self.value_dense(inputs)
        scores = tf.matmul(q, k, transpose_b=True)
        d_k = tf.cast(self.d_model, tf.float32)
        scaled_scores = scores / tf.math.sqrt(d_k)
        attention_weights = tf.nn.softmax(scaled_scores, axis=-1)
        output = tf.matmul(attention_weights, v)
        
        return output
    
inputs = tf.random.uniform((1, 60, 512))
self_attention = SelfAttention(d_model=512)
output = self_attention(inputs)
print(output.shape)
# Out:
# (1, 60, 512)

# %%
import tensorflow as tf
# Error 1: 'Layer' was not imported
from tensorflow.keras.layers import Layer 
from tensorflow.keras.models import Sequential

class TransformerEncoder(Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(TransformerEncoder, self).__init__()
        
        self.mha = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
        self.ffn = tf.keras.layers.Sequential([
            tf.keras.layers.Dense(dff, activation='relu'),
            tf.keras.layers.Dense(d_model)
        ])
        
        # Error 2: Typo in 'LayerNormalization'
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.dropout1 = tf.keras.layers.Dropout(rate)   
        self.dropout2 = tf.keras.layers.Dropout(rate)
        
    # Error 3: Typo in 'training' argument
    def call(self, x, training, mask):
        # Error 4: Typo in 'self.mha'
        attn_output = self.mha(x, x, x, attention_mask=mask)
        
        # Error 5: 'training' argument was misspelled and passed incorrectly
        attn_output = self.dropout1(attn_output, training=training)
        
        out1 = self.layernorm1(x + attn_output)
        ffn_output = self.ffn(out1)
        
        # Error 6: 'training' argument was missing
        ffn_output = self.dropout2(ffn_output, training=training)
        
        out2 = self.layernorm2(out1 + ffn_output)
        return out2

# --- Example Usage ---
d_model = 512
encoder = TransformerEncoder(d_model=d_model, num_heads=8, dff=2048)
x = tf.random.uniform((1, 60, d_model))
mask = None 

# You must pass the 'training' argument (e.g., True or False)
output = encoder(x, training=False, mask=mask) 

print(output.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 26
#      23         out2 = self.layernorm2(out1 + ffn_output)
#      24         return out2
# ---> 26 encoder = TransformerEncoder(d_model = 512, num_heads= 8, dff= 2048)
#      27 x = tf.random.uniform((1, 60, 512))
#      28 mask = None
#
# Cell In[11], line 7, in TransformerEncoder.__init__(self, d_model, num_heads, dff, rate)
#       4 super(TransformerEncoder, self).__init__()
#       6 self.mha = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
# ----> 7 self.ffn = tf.keras.layers.Sequential([
#       8     tf.keras.layers.Dense(dff, activation='relu'),
#       9     tf.keras.layers.Dense(d_model)
#      10 ])
#      12 self.layernorm1 = tf.keras.layers.LayerNomralization(epsilon = 1e-6)
#      13 self.layernorm2 = tf.keras.layers.LayerNomralization(epsilon = 1e-6)
#
# ...
